# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e559fc3d-3857-4c9d-aad9-d9210ea37f40" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e559fc3d-3857-4c9d-aad9-d9210ea37f40">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # New Section

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('StudentsPerformance.csv')

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# NUMBER OF MALES AND FEMALE PARTICIPATED IN THE TEST

# %%
plt.hist(data['gender'])
plt.show()

# %%
1)number of females participated in test=525
  number of males participated in the test=475

# %%
plt.hist(data['math score'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.hist(data['reading score'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.hist(data['writing score'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
data['math score'].mean()
# Out:
# 66.001

# %%
data['reading score'].mean()
# Out:
# 69.195

# %%
data['writing score'].mean()
# Out:
# 68.119

# %%
plt.scatter(data['gender'],data['math score'],data['reading score'],data['writing score'])

# %%
data.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %%
data['math score'].quantile()
# Out:
# 66.0

# %%
data['math score'].quantile(0.25)
# Out:
# 57.0
